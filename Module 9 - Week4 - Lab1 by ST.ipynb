# %% [markdown]
# #                                  Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Title: Explore new business opportunities in various cities in NC state

# %% [markdown]
# ### Introduction & Business problem

# %% [markdown]
# A businessman wants to start a new business in North Carolina, USA. For him to decide in which city he shall make investment to start the business, he wants to explore the following data:
# 1)	What are the top-10 most populous cities in NC state?
# 2)	What are the various businesses in these cities?
# 3)	What is the count of each these businesses in each of the Top-10 cities?
# 4)	What are the 10 most common  & least common businesses per every 10,000 population in these cities?

# %% [markdown]
# Fortunately for the businessman, also for all other potential investors/businesses, we can provide this information using Data Science methodologies & Python language.

# %% [markdown]
# ### Solution approach and Data points

# %% [markdown]
# Here are the data points that we need for this project:
#
# 1)	Identify the Top-10 cities in NC by population: This data may be available on the Internet.
# 2)	Address info (i.e. longitude & latitude) for the top-10 cities.
# 3)	Identify & explore various businesses, venues in these cities.
# 4)	Identify the no. of businesses, their frequency, top-10 most/least common businesses in these cities and calculate them for every 10k population.
# 5)	Identify the business densities in these cities using above data points.

# %% [markdown]
# #### Data Sources:
# Here are the sources for this data:
#
# 1) List of NC cities by population is available on Internet at the following website:
#
# https://worldpopulationreview.com/states/cities/north-carolina
#
# 2)	We can get the longitude & latitude of the top-10 cities using geopy.geocoders.
# 3)	Using the longitude & latitude values from above step, we can explore the various businesses, venues in these cities using Foursquare API.
# 4)	We can identify the no. of businesses, frequency, most common, least common businesses using data from above step & city population.
# 5)	We can visualize the business densities in these cities using Folium visualization library.

# %% [markdown]
# ## Download and Explore data sets

# %% [markdown]
# #### First download all the required libraries/packages

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0          conda-forge
#     geopy:           2.0.0-pyh9f0ad1d_0 conda-forge
#     python_abi:      3.6-1_cp36m        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0               --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0              --> 1.1.1g-h516909a_0        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                    --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# #### Load and explore the first data set (i.e. NC Population by City)

# %%
url = 'https://worldpopulationreview.com/states/cities/north-carolina'
html = requests.get(url).content
df_list = pd.read_html(html)
df_list
# Out:
# [     Rank                 Name  2020 Pop  2010 Census   Change  Density (km²)
#  0       1            Charlotte    905318       738534   22.58%           1138
#  1       2              Raleigh    481958       406355   18.61%           1276
#  2       3           Greensboro    299946       269587   11.26%            897
#  3       4               Durham    282737       230710   22.55%            973
#  4       5        Winston-Salem    251762       230033    9.45%            733
#  5       6         Fayetteville    205646       208335   -1.29%            537
#  6       7                 Cary    175102       137021   27.79%           1151
#  7       8           Wilmington    126669       106750   18.66%            951
#  8       9           High Point    112900       104697    7.83%            779
#  9      10              Concord     98842        79510   24.31%            601
#  10     11           Greenville     95183        85109   11.84%           1031
#  11     12            Asheville     93758        83471   12.32%            794
#  12     13             Gastonia     79784        71710   11.26%            596
#  13     14         Jacksonville     72926        77929   -6.42%            579
#  14     15                 Apex     59842        37885   57.96%           1111
#  15     16          Chapel Hill     59606        57402    3.84%           1069
#  16     17         Huntersville     59260        46959   26.20%            562
#  17     18           Burlington     55720        50959    9.34%            722
#  18     19          Rocky Mount     53524        57685   -7.21%            468
#  19     20           Kannapolis     52147        42685   22.17%            617
#  20     21               Wilson     49415        49214    0.41%            613
#  21     22          Wake Forest     48048        30354   58.29%           1052
#  22     23              Hickory     41595        40015    3.95%            542
#  23     24         Indian Trail     41059        33718   21.77%            722
#  24     25        Holly Springs     40481        24935   62.35%            917
#  25     26          Mooresville     39725        34402   15.47%            623
#  26     27               Monroe     36183        32857   10.12%            461
#  27     28            Salisbury     34058        33490    1.70%            590
#  28     29             Matthews     33891        27299   24.15%            765
#  29     30        Fuquay-Varina     33080        18212   81.64%            841
#  ..    ...                  ...       ...          ...      ...            ...
#  470   471             Columbia       786          857   -8.28%            252
#  471   472            Northwest       784          729    7.54%             43
#  472   473          Chocowinity       783          783    0.00%            300
#  473   474         Stantonsburg       782          786   -0.51%            513
#  474   475          Hightsville       777          739    5.14%            206
#  475   476          Black Creek       774          767    0.91%            417
#  476   477           White Lake       770          816   -5.64%            290
#  477   478               Wagram       769          838   -8.23%            204
#  478   479             Aulander       769          896  -14.17%            201
#  479   480          Misenheimer       767          728    5.36%            165
#  480   481            Red Cross       765          737    3.80%             83
#  481   482          High Shoals       752          702    7.12%            112
#  482   483             Alliance       752          778   -3.34%            139
#  483   484  North Topsail Beach       751          745    0.81%             47
#  484   485         Iron Station       743          755   -1.59%            122
#  485   486            Hollister       740          674    9.79%             73
#  486   487               Camden       740          599   23.54%            181
#  487   488      Jackson Heights       739         1141  -35.23%            196
#  488   489             Clarkton       737          841  -12.37%            228
#  489   490              Moncure       732          711    2.95%             60
#  490   491             Peletier       723          701    3.14%             77
#  491   492               Conway       720          831  -13.36%            152
#  492   493               Winton       717          769   -6.76%            342
#  493   494               Stokes       716          376   90.43%             62
#  494   495           Riegelwood       712          579   22.97%             89
#  495   496                Bogue       710          688    3.20%            100
#  496   497               Efland       709          734   -3.41%            154
#  497   498               Grover       705          707   -0.28%            285
#  498   499            Whitakers       696          745   -6.58%            327
#  499   500            Rougemont       695          978  -28.94%             43
#
#  [500 rows x 6 columns]]

# %% [markdown]
# ### Install the required libraries/packages for identifying the longitude & latitude

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ### Sample code for getting address, venue info for the first city. This will be expanded to other cities in the next lab assignment.

# %%
address1 = 'Charlotte, NC'
geolocator = Nominatim(user_agent="ny_explorer")
location1 = geolocator.geocode(address1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of Charlotte City are {}, {}.'.format(latitude1, longitude1))
# Out:
# The geograpical coordinate of Charlotte City are 35.2272, -80.843083.

# %% [markdown]
# #### Extracting Foursquare location data for first city (This will be expanded to other cities in the next lab)

# %%
CLIENT_ID = 'MSNMMGSCRZIA0SASHUDGUISUSIUL2NM2UZNLLOD5VUGC3KA2' # your Foursquare ID
CLIENT_SECRET = 'PBKYG2N2JJQAMSAW0DBNWUDTGGENQTI2NJ5OOX4B04EEXMFB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MSNMMGSCRZIA0SASHUDGUISUSIUL2NM2UZNLLOD5VUGC3KA2
# CLIENT_SECRET:PBKYG2N2JJQAMSAW0DBNWUDTGGENQTI2NJ5OOX4B04EEXMFB

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude1, 
    longitude1, 
    radius, 
    LIMIT)
url1
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=MSNMMGSCRZIA0SASHUDGUISUSIUL2NM2UZNLLOD5VUGC3KA2&client_secret=PBKYG2N2JJQAMSAW0DBNWUDTGGENQTI2NJ5OOX4B04EEXMFB&v=20180605&ll=35.2272,-80.843083&radius=500&limit=100'

# %%
results = requests.get(url1).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f0e2a93ca618c567bc5e447'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Fourth Ward',
#   'headerFullLocation': 'Fourth Ward, Charlotte',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 119,
#   'suggestedBounds': {'ne': {'lat': 35.231700004500006,
#     'lng': -80.83758445541405},
#    'sw': {'lat': 35.2226999955, 'lng': -80.84858154458594}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bad5829f964a52071483be3',
#        'name': 'Blumenthal Performing Arts Center',
#        'location': {'address': '130 N Tryon St',
#         'crossStreet': 'at 5th St',
#         'lat': 35.22792953956913,
#         'lng': -80.84195071274344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22792953956913,
#           'lng': -80.84195071274344}],
#         'distance': 131,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['130 N Tryon St (at 5th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bad5829f964a52071483be3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058640f964a520495a22e3',
#        'name': 'Belk Theater',
#        'location': {'address': '130 N Tryon St',
#         'lat': 35.2277106677568,
#         'lng': -80.84166327548685,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.2277106677568,
#           'lng': -80.84166327548685}],
#         'distance': 141,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['130 N Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058640f964a520495a22e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05863ef964a520f45922e3',
#        'name': 'The Capital Grille',
#        'location': {'address': '201 N Tryon St',
#         'crossStreet': 'at E 5th St',
#         'lat': 35.22821596511468,
#         'lng': -80.84197405615006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22821596511468,
#           'lng': -80.84197405615006}],
#         'distance': 151,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['201 N Tryon St (at E 5th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05863ef964a520f45922e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549af5b3498e3a660685323b',
#        'name': 'The Punch Room',
#        'location': {'address': '201 E Trade St',
#         'lat': 35.22635447916386,
#         'lng': -80.84174681535497,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22635447916386,
#           'lng': -80.84174681535497}],
#         'distance': 153,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['201 E Trade St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-549af5b3498e3a660685323b-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2ffb921838f1c552ca5f70',
#        'name': 'Vapiano',
#        'location': {'address': '201 S Tryon St',
#         'crossStreet': 'E 4th St',
#         'lat': 35.226234166101676,
#         'lng': -80.84412438023452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226234166101676,
#           'lng': -80.84412438023452}],
#         'distance': 143,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['201 S Tryon St (E 4th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39015880'}},
#       'referralId': 'e-0-4e2ffb921838f1c552ca5f70-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b466381f964a5206f1f26e3',
#        'name': 'Dandelion Market',
#        'location': {'address': '118 W 5th St',
#         'crossStreet': 'N Church St',
#         'lat': 35.2286559557103,
#         'lng': -80.8424793686398,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.2286559557103,
#           'lng': -80.8424793686398}],
#         'distance': 171,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['118 W 5th St (N Church St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '38261696'}},
#       'referralId': 'e-0-4b466381f964a5206f1f26e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af8ba4cf964a520830f22e3',
#        'name': 'Chima Brazilian Steakhouse',
#        'location': {'address': '139 S Tryon St',
#         'crossStreet': 'at 4th St',
#         'lat': 35.226259,
#         'lng': -80.843737,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 35.226419,
#           'lng': -80.843943},
#          {'label': 'display', 'lat': 35.226259, 'lng': -80.843737}],
#         'distance': 120,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['139 S Tryon St (at 4th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46485464'}},
#       'referralId': 'e-0-4af8ba4cf964a520830f22e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b09c3fef964a520311d23e3',
#        'name': 'Basil Thai Cuisine',
#        'location': {'address': '210 N Church St',
#         'crossStreet': 'W 5th St',
#         'lat': 35.228940919235875,
#         'lng': -80.84280568291942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.228940919235875,
#           'lng': -80.84280568291942}],
#         'distance': 195,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['210 N Church St (W 5th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b09c3fef964a520311d23e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bddce0ae75c0f476dadc503',
#        'name': 'Charlotte Athletic Club: Trade & Tryon',
#        'location': {'address': '101 S Tryon St Ste 200',
#         'crossStreet': 'Trade Street',
#         'lat': 35.226237988641934,
#         'lng': -80.84289675731058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226237988641934,
#           'lng': -80.84289675731058}],
#         'distance': 108,
#         'postalCode': '28280',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['101 S Tryon St Ste 200 (Trade Street)',
#          'Charlotte, NC 28280',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bddce0ae75c0f476dadc503-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b25a00ff964a520b67424e3',
#        'name': "Ruth's Chris Steak House",
#        'location': {'address': '222 S Tryon St',
#         'crossStreet': 'at 3rd St',
#         'lat': 35.22615835537083,
#         'lng': -80.84515392780304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22615835537083,
#           'lng': -80.84515392780304},
#          {'label': 'entrance', 'lat': 35.226064, 'lng': -80.845006}],
#         'distance': 221,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['222 S Tryon St (at 3rd St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b25a00ff964a520b67424e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f8b5454e4b00a6263a38774',
#        'name': '5 Church',
#        'location': {'address': '127 N Tryon St #8',
#         'crossStreet': '5th St.',
#         'lat': 35.228548239358275,
#         'lng': -80.84305375641406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.228548239358275,
#           'lng': -80.84305375641406}],
#         'distance': 150,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['127 N Tryon St #8 (5th St.)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2140944',
#         'url': 'https://www.grubhub.com/restaurant/5church-127-n-tryon-st-charlotte/2140944?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2140944',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f8b5454e4b00a6263a38774-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '512ce91be4b049302dc9d4cb',
#        'name': 'Cowbell Burger & Bar',
#        'location': {'address': '201 N Tryon St',
#         'crossStreet': 'At 5th St',
#         'lat': 35.2283706749389,
#         'lng': -80.84219607653625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.2283706749389,
#           'lng': -80.84219607653625}],
#         'distance': 153,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['201 N Tryon St (At 5th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '49799813'}},
#       'referralId': 'e-0-512ce91be4b049302dc9d4cb-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9a5bf18163a35d26ec597e',
#        'name': 'Epicentre',
#        'location': {'address': '210 East Trade Street',
#         'crossStreet': 'College St.',
#         'lat': 35.225615402649694,
#         'lng': -80.84198083366203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.225615402649694,
#           'lng': -80.84198083366203},
#          {'label': 'entrance', 'lat': 35.225946, 'lng': -80.841868}],
#         'distance': 202,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['210 East Trade Street (College St.)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '35687314'}},
#       'referralId': 'e-0-4d9a5bf18163a35d26ec597e-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b001776f964a520b93a22e3',
#        'name': 'BLT Steak',
#        'location': {'address': '110 North College Street, The Ritz-Carlton',
#         'crossStreet': 'at E Trade St',
#         'lat': 35.226289,
#         'lng': -80.841601,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226289,
#           'lng': -80.841601}],
#         'distance': 168,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['110 North College Street, The Ritz-Carlton (at E Trade St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '318746',
#         'url': 'https://www.grubhub.com/restaurant/blt-steak-110-n-college-st-charlotte/318746?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=318746',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34928912'}},
#       'referralId': 'e-0-4b001776f964a520b93a22e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a85cb7498ebb2205737e6d',
#        'name': 'Coco and the Director',
#        'location': {'address': '100 W Trade St',
#         'lat': 35.22768360609232,
#         'lng': -80.84354843212633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22768360609232,
#           'lng': -80.84354843212633}],
#         'distance': 68,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['100 W Trade St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1317945',
#         'url': 'https://www.grubhub.com/restaurant/coco-and-the-director-100-west-trade-street-charlotte/1317945?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1317945',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a85cb7498ebb2205737e6d-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f516ba8e4b063296bf04765',
#        'name': "Rooster's Wood Fired Kitchen II",
#        'location': {'address': '150 N College St',
#         'crossStreet': '5th',
#         'lat': 35.22685570393458,
#         'lng': -80.84122928706151,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22685570393458,
#           'lng': -80.84122928706151}],
#         'distance': 172,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['150 N College St (5th)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f516ba8e4b063296bf04765-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a56d1f498e5952a14f86f4',
#        'name': 'Stoke',
#        'location': {'address': '100 W Trade St',
#         'lat': 35.22805695575986,
#         'lng': -80.84347536770582,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22805695575986,
#           'lng': -80.84347536770582}],
#         'distance': 101,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['100 W Trade St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a56d1f498e5952a14f86f4-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511e6b27e4b0d5834393f063',
#        'name': "Uncle Maddio's Pizza",
#        'location': {'address': '101 S. Tryon St.',
#         'lat': 35.225999,
#         'lng': -80.843157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.225999,
#           'lng': -80.843157}],
#         'distance': 133,
#         'postalCode': '28280',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['101 S. Tryon St.',
#          'Charlotte, NC 28280',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '529005',
#         'url': 'https://www.grubhub.com/restaurant/uncle-maddios-pizza-joint-101-s-tryon-st-charlotte/529005?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=529005',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-511e6b27e4b0d5834393f063-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058640f964a5205b5a22e3',
#        'name': 'Booth Playhouse',
#        'location': {'address': '130 N Tryon St',
#         'lat': 35.227001085120676,
#         'lng': -80.8412642147841,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.227001085120676,
#           'lng': -80.8412642147841}],
#         'distance': 166,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['130 N Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058640f964a5205b5a22e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f6a445ce4b0ac9953bbcdd9',
#        'name': 'Hazelnuts Creperie',
#        'location': {'address': '200 S Tryon St Lbby',
#         'crossStreet': '4th',
#         'lat': 35.226509958342255,
#         'lng': -80.84447703166754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226509958342255,
#           'lng': -80.84447703166754}],
#         'distance': 148,
#         'postalCode': '28202',
#         'cc': 'US',
#         'neighborhood': 'Third Ward',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['200 S Tryon St Lbby (4th)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1339269',
#         'url': 'https://www.grubhub.com/restaurant/hazelnuts-creperie-200-s-tryon-st-charlotte/1339269?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1339269',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32823795'}},
#       'referralId': 'e-0-4f6a445ce4b0ac9953bbcdd9-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '576eb02b498e5c4439a993cd',
#        'name': 'Not Just Coffee',
#        'location': {'address': '222 S Church St',
#         'lat': 35.226891343243366,
#         'lng': -80.84612588431538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226891343243366,
#           'lng': -80.84612588431538},
#          {'label': 'entrance', 'lat': 35.227091, 'lng': -80.845793}],
#         'distance': 278,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['222 S Church St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-576eb02b498e5c4439a993cd-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb14a46f964a520fa893ce3',
#        'name': 'Aria Tuscan Grill',
#        'location': {'address': '100 N Tryon St',
#         'lat': 35.22661542645824,
#         'lng': -80.84231735380716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22661542645824,
#           'lng': -80.84231735380716}],
#         'distance': 95,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['100 N Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '603380',
#         'url': 'https://www.grubhub.com/restaurant/aria-tuscan-grill-100-n-tryon-st-charlotte/603380?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=603380',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb14a46f964a520fa893ce3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e84b7815503e18a129b1cb4',
#        'name': 'Bar Cocoa at The Ritz-Carlton',
#        'location': {'address': '201 E Trade St',
#         'crossStreet': 'College St',
#         'lat': 35.22624234549645,
#         'lng': -80.84160402417183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22624234549645,
#           'lng': -80.84160402417183}],
#         'distance': 171,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['201 E Trade St (College St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1991237',
#         'url': 'https://www.grubhub.com/restaurant/bar-cocoa-201-east-trade-street-charlotte/1991237?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1991237',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e84b7815503e18a129b1cb4-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b218414f964a520103d24e3',
#        'name': 'Emerson Joseph',
#        'location': {'address': '221 S Tryon St',
#         'lat': 35.226049478423356,
#         'lng': -80.84469205823395,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226049478423356,
#           'lng': -80.84469205823395}],
#         'distance': 194,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['221 S Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110951735',
#          'name': 'Salon / Barbershop',
#          'pluralName': 'Salons / Barbershops',
#          'shortName': 'Salon / Barbershop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '67108532'}},
#       'referralId': 'e-0-4b218414f964a520103d24e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058639f964a520155922e3',
#        'name': 'Charlotte Marriott City Center',
#        'location': {'address': '100 W Trade St',
#         'lat': 35.22793089328217,
#         'lng': -80.84357142448425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22793089328217,
#           'lng': -80.84357142448425}],
#         'distance': 92,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['100 W Trade St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '131904962'}},
#       'referralId': 'e-0-4b058639f964a520155922e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae7e6746bdee6002c84ed22',
#        'name': "Eddie V's Prime Seafood",
#        'location': {'address': '101 S Tryon St',
#         'crossStreet': 'E Trade St',
#         'lat': 35.226874574535124,
#         'lng': -80.84325993312943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226874574535124,
#           'lng': -80.84325993312943}],
#         'distance': 39,
#         'postalCode': '28280',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['101 S Tryon St (E Trade St)',
#          'Charlotte, NC 28280',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ae7e6746bdee6002c84ed22-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b075a9af964a52086fc22e3',
#        'name': 'Room 112',
#        'location': {'address': '112 S Tryon St',
#         'crossStreet': 'Corner of Trade and Tryon',
#         'lat': 35.227335128656165,
#         'lng': -80.84348421841464,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.227335128656165,
#           'lng': -80.84348421841464},
#          {'label': 'entrance', 'lat': 35.22735, 'lng': -80.843808}],
#         'distance': 39,
#         'postalCode': '28284',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['112 S Tryon St (Corner of Trade and Tryon)',
#          'Charlotte, NC 28284',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b075a9af964a52086fc22e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058642f964a5209a5a22e3',
#        'name': 'Discovery Place',
#        'location': {'address': '301 N Tryon St',
#         'crossStreet': '7th St',
#         'lat': 35.22917975335418,
#         'lng': -80.84081411361694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22917975335418,
#           'lng': -80.84081411361694}],
#         'distance': 301,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['301 N Tryon St (7th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d191941735',
#          'name': 'Science Museum',
#          'pluralName': 'Science Museums',
#          'shortName': 'Science Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '448074002'}},
#       'referralId': 'e-0-4b058642f964a5209a5a22e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05863bf964a520785922e3',
#        'name': 'Rí Rá Irish Pub',
#        'location': {'address': '208 N Tryon St',
#         'crossStreet': '5th St',
#         'lat': 35.22813441698387,
#         'lng': -80.84158201144281,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22813441698387,
#           'lng': -80.84158201144281},
#          {'label': 'entrance', 'lat': 35.228065, 'lng': -80.841605}],
#         'distance': 171,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['208 N Tryon St (5th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a06',
#          'name': 'Irish Pub',
#          'pluralName': 'Irish Pubs',
#          'shortName': 'Irish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34716678'}},
#       'referralId': 'e-0-4b05863bf964a520785922e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1980d9f964a52088de23e3',
#        'name': "Fleming's Prime Steakhouse & Wine Bar",
#        'location': {'address': '210 E Trade St Ste C110',
#         'crossStreet': '@ 4th St',
#         'lat': 35.22541782185265,
#         'lng': -80.84204892822439,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22541782185265,
#           'lng': -80.84204892822439}],
#         'distance': 219,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['210 E Trade St Ste C110 (@ 4th St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1980d9f964a52088de23e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5df82ff964a520b17629e3',
#        'name': 'Energy Cafe',
#        'location': {'address': '101 S Tryon St',
#         'crossStreet': 'Bank of America Plaza',
#         'lat': 35.226263680976686,
#         'lng': -80.84282203421708,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.226263680976686,
#           'lng': -80.84282203421708}],
#         'distance': 106,
#         'postalCode': '28280',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['101 S Tryon St (Bank of America Plaza)',
#          'Charlotte, NC 28280',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5df82ff964a520b17629e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c76b41eb4b4b60c2e52250e',
#        'name': 'The Square',
#        'location': {'address': 'W Trade St.',
#         'crossStreet': 'at Tryon St.',
#         'lat': 35.22720670013183,
#         'lng': -80.84306953733282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22720670013183,
#           'lng': -80.84306953733282}],
#         'distance': 1,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['W Trade St. (at Tryon St.)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c76b41eb4b4b60c2e52250e-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f02453e30f899233495e903',
#        'name': 'Malabar',
#        'location': {'address': '214 N Tryon St',
#         'lat': 35.22832403668747,
#         'lng': -80.84140355110613,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22832403668747,
#           'lng': -80.84140355110613}],
#         'distance': 197,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['214 N Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1469570',
#         'url': 'https://www.grubhub.com/restaurant/malabar-214-north-tryon-street-charlotte/1469570?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1469570',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f02453e30f899233495e903-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058640f964a5205e5a22e3',
#        'name': 'McGlohon Theatre',
#        'location': {'address': '345 N College St',
#         'lat': 35.22921191726555,
#         'lng': -80.83991387982292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22921191726555,
#           'lng': -80.83991387982292}],
#         'distance': 364,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['345 N College St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058640f964a5205e5a22e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4a7e43f964a520368926e3',
#        'name': 'Smoothie King',
#        'location': {'address': '210 E. Trade St.',
#         'crossStreet': 'EpiCentre 2nd Level',
#         'lat': 35.225545,
#         'lng': -80.842321,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.225545,
#           'lng': -80.842321},
#          {'label': 'entrance', 'lat': 35.225946, 'lng': -80.841868}],
#         'distance': 196,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['210 E. Trade St. (EpiCentre 2nd Level)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b41',
#          'name': 'Smoothie Shop',
#          'pluralName': 'Smoothie Shops',
#          'shortName': 'Smoothie Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4a7e43f964a520368926e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59e10d20bcbf7a4735d6d29c',
#        'name': 'Kimpton Tryon Park Hotel',
#        'location': {'address': '303 S Church St',
#         'lat': 35.225820810865045,
#         'lng': -80.84607868161794,
#         'labeledLatLngs': [{'label': 'display',
# ...
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-599b7687cf72a01493e2f769-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8507360039d4b51c9ad6bb',
#        'name': 'Wells Fargo History Museum',
#        'location': {'address': '401 S Tryon St',
#         'lat': 35.22443668794185,
#         'lng': -80.84659791288493,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22443668794185,
#           'lng': -80.84659791288493},
#          {'label': 'entrance', 'lat': 35.224727, 'lng': -80.846443}],
#         'distance': 443,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['401 S Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8507360039d4b51c9ad6bb-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b11d4c9f964a5209d8523e3',
#        'name': 'KO Sushi',
#        'location': {'address': '230 S Tryon St',
#         'crossStreet': '3rd St',
#         'lat': 35.22585949985494,
#         'lng': -80.84570126670798,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22585949985494,
#           'lng': -80.84570126670798},
#          {'label': 'entrance', 'lat': 35.225885, 'lng': -80.845213}],
#         'distance': 280,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['230 S Tryon St (3rd St)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b11d4c9f964a5209d8523e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058640f964a520465a22e3',
#        'name': 'IMAX Dome Theater at Discovery Place',
#        'location': {'address': '301 N Tryon St',
#         'lat': 35.22968752981986,
#         'lng': -80.84176836308474,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22968752981986,
#           'lng': -80.84176836308474}],
#         'distance': 301,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['301 N Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058640f964a520465a22e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dea29bafa76cc1b8adcdc18',
#        'name': 'Hyatt House Charlotte/Center City',
#        'location': {'address': '435 E Trade St',
#         'lat': 35.22412104866454,
#         'lng': -80.83912237234372,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22412104866454,
#           'lng': -80.83912237234372}],
#         'distance': 497,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['435 E Trade St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dea29bafa76cc1b8adcdc18-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1fb1dd920076b0a527c5e9',
#        'name': 'Smoothie King',
#        'location': {'address': '301 S. College Street',
#         'lat': 35.224087,
#         'lng': -80.844691,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.224087,
#           'lng': -80.844691},
#          {'label': 'entrance', 'lat': 35.223865, 'lng': -80.844296}],
#         'distance': 376,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['301 S. College Street',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b41',
#          'name': 'Smoothie Shop',
#          'pluralName': 'Smoothie Shops',
#          'shortName': 'Smoothie Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1fb1dd920076b0a527c5e9-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54809348498e1857be678706',
#        'name': 'Hazelnuts Creperie',
#        'location': {'lat': 35.22753470831983,
#         'lng': -80.83798374744796,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22753470831983,
#           'lng': -80.83798374744796}],
#         'distance': 465,
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['Charlotte, NC', 'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54809348498e1857be678706-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5df460079d0cab000795abfa',
#        'name': 'Chipotle Mexican Grill',
#        'location': {'address': '316 S Tryon St',
#         'lat': 35.22536753301664,
#         'lng': -80.84618329816493,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22536753301664,
#           'lng': -80.84618329816493}],
#         'distance': 347,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['316 S Tryon St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5df460079d0cab000795abfa-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc367d3904a59363334d9e',
#        'name': '4th Ward Neighborhood Park',
#        'location': {'address': '301 N Poplar St',
#         'lat': 35.231321,
#         'lng': -80.842796,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.231321,
#           'lng': -80.842796}],
#         'distance': 459,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['301 N Poplar St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc367d3904a59363334d9e-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05863bf964a520775922e3',
#        'name': 'Mimosa Grill',
#        'location': {'address': '327 S Tryon St.',
#         'crossStreet': 'MLK Blvd',
#         'lat': 35.22498077623014,
#         'lng': -80.84595764506925,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22498077623014,
#           'lng': -80.84595764506925},
#          {'label': 'entrance', 'lat': 35.224774, 'lng': -80.845707}],
#         'distance': 359,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['327 S Tryon St. (MLK Blvd)',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1901578',
#         'url': 'https://www.grubhub.com/restaurant/mimosa-grill-327-south-tryon-street-charlotte/1901578?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1901578',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05863bf964a520775922e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05863af964a5203c5922e3',
#        'name': 'Hilton',
#        'location': {'address': '222 E 3rd St',
#         'lat': 35.2239649,
#         'lng': -80.8438219,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.2239649,
#           'lng': -80.8438219}],
#         'distance': 366,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['222 E 3rd St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '97431423'}},
#       'referralId': 'e-0-4b05863af964a5203c5922e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '521f745d11d2938f566fd4df',
#        'name': 'Crisp',
#        'location': {'lat': 35.225584548418695,
#         'lng': -80.84640769619477,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.225584548418695,
#           'lng': -80.84640769619477}],
#         'distance': 351,
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['Charlotte, NC', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1470605',
#         'url': 'https://www.grubhub.com/restaurant/crisp-charlotte-320-south-tryon-street-charlotte/1470605?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1470605',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-521f745d11d2938f566fd4df-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b05863bf964a520665922e3',
#        'name': "Green's Lunch",
#        'location': {'address': '309 W 4th St',
#         'lat': 35.22843524013724,
#         'lng': -80.84670158235116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 35.22843524013724,
#           'lng': -80.84670158235116},
#          {'label': 'entrance', 'lat': 35.228297, 'lng': -80.846563}],
#         'distance': 356,
#         'postalCode': '28202',
#         'cc': 'US',
#         'city': 'Charlotte',
#         'state': 'NC',
#         'country': 'United States',
#         'formattedAddress': ['309 W 4th St',
#          'Charlotte, NC 28202',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1316975',
#         'url': 'https://www.grubhub.com/restaurant/greens-lunch-309-west-4th-street-charlotte/1316975?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1316975',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b05863bf964a520665922e3-99'}]}]}}
